# %% [markdown]
# # Arrays and Hashing

# %% [markdown]
# ## Topic overview
#
# Foundational patterns for direct-access and hash-backed lookup.

# %% [markdown]
# ## Pattern-recognition rules
#
# - Frequency counting with `collections.Counter`.
# - Set membership for O(1) presence checks.
# - Prefix/suffix products.
# - Prefix sums.

# %% [markdown]
# ## Common data structures
#
# - `list`
# - `set`
# - `dict`
# - `collections.Counter`

# %% [markdown]
# ## Standard complexity expectations
#
# - Time O(n) with O(n) space is usually optimal.
# - Beware of hashability of inputs.

# %% [markdown]
# ## Common mistakes
#
# - Forgetting to handle empty input.
# - Mutating a dict while iterating.

# %% [markdown]
# ## Original illustrative example

# %%
# Replace with an ORIGINAL example. Do not paste external
# problem statements. See src/algorithms/ for reusable helpers.
example_input = []
example_expected = None

# %% [markdown]
# ## Add solved problems below
#
# Each new sub-section should follow the template in `../templates/notebook_template.ipynb`.

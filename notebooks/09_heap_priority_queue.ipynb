# %% [markdown]
# # Heap / Priority Queue

# %% [markdown]
# ## Topic overview
#
# Min/max access in log time.

# %% [markdown]
# ## Pattern-recognition rules
#
# - Top-K with a heap of size K.
# - Streaming median with two heaps.
# - Dijkstra-style relaxation.

# %% [markdown]
# ## Common data structures
#
# - `heapq` (min-heap)
# - Negation trick for max-heap

# %% [markdown]
# ## Standard complexity expectations
#
# - Push/pop are O(log n).

# %% [markdown]
# ## Common mistakes
#
# - Forgetting Python's `heapq` is a min-heap only.
# - Comparing tuples with non-comparable secondary keys.

# %% [markdown]
# ## Original illustrative example

# %%
# Replace with an ORIGINAL example. Do not paste external
# problem statements. See src/algorithms/ for reusable helpers.
example_input = []
example_expected = None

# %% [markdown]
# ## Add solved problems below
#
# Each new sub-section should follow the template in `../templates/notebook_template.ipynb`.

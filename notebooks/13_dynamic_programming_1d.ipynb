# %% [markdown]
# # Dynamic Programming — 1D

# %% [markdown]
# ## Topic overview
#
# State lives on a single axis; transition looks back a bounded window.

# %% [markdown]
# ## Pattern-recognition rules
#
# - Define state precisely ("dp[i] = ...").
# - Write the recurrence before writing code.
# - Compress space when only the last k states are needed.

# %% [markdown]
# ## Common data structures
#
# - `list` for `dp`
# - Two rolling scalars

# %% [markdown]
# ## Standard complexity expectations
#
# - Usually O(n) time, O(n) or O(1) space.

# %% [markdown]
# ## Common mistakes
#
# - Off-by-one in the base case.
# - Recurrence that reads a state not yet computed.

# %% [markdown]
# ## Original illustrative example

# %%
# Replace with an ORIGINAL example. Do not paste external
# problem statements. See src/algorithms/ for reusable helpers.
example_input = []
example_expected = None

# %% [markdown]
# ## Add solved problems below
#
# Each new sub-section should follow the template in `../templates/notebook_template.ipynb`.

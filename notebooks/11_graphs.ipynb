# %% [markdown]
# # Graphs

# %% [markdown]
# ## Topic overview
#
# BFS/DFS over adjacency structures.

# %% [markdown]
# ## Pattern-recognition rules
#
# - Grid problems as implicit graphs.
# - Visited sets to avoid revisits.
# - Multi-source BFS.

# %% [markdown]
# ## Common data structures
#
# - Adjacency list
# - Adjacency matrix

# %% [markdown]
# ## Standard complexity expectations
#
# - BFS/DFS both O(V+E).

# %% [markdown]
# ## Common mistakes
#
# - Revisiting a node because 'visited' is checked at the wrong time.
# - Confusing directed vs undirected.

# %% [markdown]
# ## Original illustrative example

# %%
# Replace with an ORIGINAL example. Do not paste external
# problem statements. See src/algorithms/ for reusable helpers.
example_input = []
example_expected = None

# %% [markdown]
# ## Add solved problems below
#
# Each new sub-section should follow the template in `../templates/notebook_template.ipynb`.

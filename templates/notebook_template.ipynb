# %% [markdown]
# # {{PROBLEM_OR_TOPIC_NAME}}
#
# ## Metadata
#
# - Source:
# - Problem URL:
# - Difficulty:
# - Topic:
# - Date started:
# - Date solved:
# - Current mastery level:
# - Last reviewed:
# - Next review:

# %% [markdown]
# ## Problem statement in my own words
#
# _Do not copy the platform's wording. Restate the problem in a way that would let a peer implement it from scratch._

# %% [markdown]
# ## Inputs, outputs, and constraints
#
# - Inputs:
# - Outputs:
# - Constraints:

# %% [markdown]
# ## Examples
#
# | Input | Expected | Notes |
# |---|---|---|
# |  |  |  |

# %% [markdown]
# ## Initial observations

# %% [markdown]
# ## Brute-force approach
#
# ### Why it works
#
# ### Implementation

# %%
def brute_force(*args, **kwargs):
    raise NotImplementedError

# %% [markdown]
# ### Complexity
#
# - Time:
# - Space:

# %% [markdown]
# ## Optimized insight
#
# ## Optimized approach
#
# ### Step-by-step trace
#
# | Step | State | Note |
# |---|---|---|
# |  |  |  |

# %%
def optimized(*args, **kwargs):
    raise NotImplementedError

# %% [markdown]
# ## Complexity analysis
#
# - Time:
# - Space:

# %% [markdown]
# ## Edge cases
#
# - Empty input
# - Single element
# - Duplicates
# - Sorted / reverse-sorted input
# - Extreme values

# %% [markdown]
# ## Testing

# %%
# Local sanity checks. Prefer full pytest tests next to the .py file.
assert True

# %% [markdown]
# ## Alternative approaches
#
# ## Mistakes I made
#
# ## Pattern recognition
#
# ## Related problems
#
# ## Real-world or engineering connection
#
# ## Final takeaways

# %% [markdown]
# ## Reattempt log
#
# | Date | Mastery | Notes |
# |---|---|---|
